# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("../data/raw/dht11_new.csv")  # Replace "your_data.csv" with the actual file name

# Display the first few rows to get an overview of the dataset
print("First 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#      id  temperature  humidity  mq2_analog  mq2_digital  sound_analog  \
# 0  2211         32.3      53.0       148.0          1.0         192.0
# 1  2212         32.3      53.0       148.0          1.0         184.0
# 2  2213         32.3      53.0       148.0          1.0         189.0
# 3  2214         32.3      53.0       147.0          1.0         189.0
# 4  2215         32.3      53.0       147.0          1.0         184.0
#
#    sound_digital  mq9_analog             datatime  mq9_digital  mq8_analog  \
# 0            0.0       141.0  2024-04-06 22:39:11          1.0       205.0
# 1            0.0       141.0  2024-04-06 22:39:18          1.0       205.0
# 2            0.0       141.0  2024-04-06 22:39:24          1.0       205.0
# 3            0.0       141.0  2024-04-06 22:39:31          1.0       205.0
# 4            0.0       141.0  2024-04-06 22:39:38          1.0       205.0
#
#    mq8_digital  pm25_density  pm10_density
# 0          1.0        242.28        186.67
# 1          1.0        233.98        189.99
# 2          1.0        246.43        212.40
# 3          1.0        234.81        183.35
# 4          1.0        237.30        221.53

# %%
data
# Out:
#           id  temperature  humidity  mq2_analog  mq2_digital  sound_analog  \
# 0       2211         32.3      53.0       148.0          1.0         192.0
# 1       2212         32.3      53.0       148.0          1.0         184.0
# 2       2213         32.3      53.0       148.0          1.0         189.0
# 3       2214         32.3      53.0       147.0          1.0         189.0
# 4       2215         32.3      53.0       147.0          1.0         184.0
# ...      ...          ...       ...         ...          ...           ...
# 53309  55520         28.9      40.0        48.0          1.0         147.0
# 53310  55521         28.9      40.0        48.0          1.0         144.0
# 53311  55522         28.9      40.0        46.0          1.0         137.0
# 53312  55523         28.9      40.0        48.0          1.0         142.0
# 53313  55524         28.9      40.0        48.0          1.0         149.0
#
#        sound_digital  mq9_analog             datatime  mq9_digital  \
# 0                0.0       141.0  2024-04-06 22:39:11          1.0
# 1                0.0       141.0  2024-04-06 22:39:18          1.0
# 2                0.0       141.0  2024-04-06 22:39:24          1.0
# 3                0.0       141.0  2024-04-06 22:39:31          1.0
# 4                0.0       141.0  2024-04-06 22:39:38          1.0
# ...              ...         ...                  ...          ...
# 53309            0.0       233.0  2024-11-21 12:16:27          1.0
# 53310            0.0       233.0  2024-11-21 12:16:34          1.0
# 53311            0.0       229.0  2024-11-21 12:16:40          1.0
# 53312            0.0       230.0  2024-11-21 12:16:47          1.0
# 53313            0.0       234.0  2024-11-21 12:16:54          1.0
#
#        mq8_analog  mq8_digital  pm25_density  pm10_density
# 0           205.0          1.0        242.28        186.67
# 1           205.0          1.0        233.98        189.99
# 2           205.0          1.0        246.43        212.40
# 3           205.0          1.0        234.81        183.35
# 4           205.0          1.0        237.30        221.53
# ...           ...          ...           ...           ...
# 53309       142.0          1.0        233.98        180.86
# 53310       140.0          1.0        234.81        188.33
# 53311       137.0          1.0        233.98        181.69
# 53312       140.0          1.0        233.15        176.71
# 53313       141.0          1.0        232.32        174.22
#
# [53314 rows x 14 columns]

# %%
# Check the shape of the dataset (number of rows and columns)
print("\nShape of the dataset (rows, columns):")
data.shape
# Out:
# Shape of the dataset (rows, columns):
# (53314, 14)

# %%
# Check column names and data types
print("\nColumn Names and Data Types:")
data.dtypes
# Out:
# Column Names and Data Types:
# id                 int64
# temperature      float64
# humidity         float64
# mq2_analog       float64
# mq2_digital      float64
# sound_analog     float64
# sound_digital    float64
# mq9_analog       float64
# datatime          object
# mq9_digital      float64
# mq8_analog       float64
# mq8_digital      float64
# pm25_density     float64
# pm10_density     float64
# dtype: object

# %%
# Check for missing values in each column
print("\nMissing Values in Each Column:")
data.isnull().sum()
# Out:
# Missing Values in Each Column:
# id               0
# temperature      0
# humidity         0
# mq2_analog       2
# mq2_digital      7
# sound_analog     3
# sound_digital    3
# mq9_analog       6
# datatime         0
# mq9_digital      4
# mq8_analog       2
# mq8_digital      4
# pm25_density     3
# pm10_density     3
# dtype: int64

# %%
# Display summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
data.describe()
# Out:
# Summary Statistics for Numerical Columns:
#                  id   temperature      humidity    mq2_analog   mq2_digital  \
# count  53314.000000  53314.000000  53314.000000  53312.000000  53307.000000
# mean   28867.500000     30.451118     46.481206     50.440557      0.984936
# std    15390.570463      7.041611     15.353280     46.993939      0.121807
# min     2211.000000    -18.600000      0.000000      0.000000      0.000000
# 25%    15539.250000     30.200000     40.000000     32.000000      1.000000
# 50%    28867.500000     32.300000     47.000000     43.000000      1.000000
# 75%    42195.750000     33.300000     54.000000     53.000000      1.000000
# max    55524.000000     40.600000     83.000000   1019.000000      1.000000
#
#        sound_analog  sound_digital    mq9_analog   mq9_digital    mq8_analog  \
# count  53311.000000   53311.000000  53308.000000  53310.000000  53312.000000
# mean     133.959295       0.108683    187.979534      0.943707    115.282282
# std       37.599592       0.311244     44.027388      0.230490     56.802895
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%      129.000000       0.000000    160.000000      1.000000     91.000000
# 50%      137.000000       0.000000    184.000000      1.000000    100.000000
# 75%      144.000000       0.000000    222.000000      1.000000    122.000000
# max      785.000000       1.000000    638.000000      1.000000   1023.000000
#
#         mq8_digital  pm25_density  pm10_density
# count  53310.000000  53311.000000  53311.000000
# mean       0.975558    230.824804    187.797825
# std        0.154418     39.716138     37.400810
# min        0.000000     -0.100000     -0.100000
# 25%        1.000000    210.740000    166.750000
# 50%        1.000000    226.510000    184.180000
# 75%        1.000000    247.260000    204.100000
# max        1.000000    849.070000    808.400000

# %%
# Check for unique values in each column to understand categorical features
print("\nUnique Values in Each Column:")
{column: data[column].nunique() for column in data.columns}
# Out:
# Unique Values in Each Column:
# {'id': 53314,
#  'temperature': 114,
#  'humidity': 58,
#  'mq2_analog': 413,
#  'mq2_digital': 2,
#  'sound_analog': 384,
#  'sound_digital': 2,
#  'mq9_analog': 388,
#  'datatime': 52238,
#  'mq9_digital': 2,
#  'mq8_analog': 513,
#  'mq8_digital': 2,
#  'pm25_density': 532,
#  'pm10_density': 539}

# %%
import matplotlib.pyplot as plt

# Ensure 'datatime' column is in datetime format
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the hour from 'datatime' for grouping
data['hour'] = data['datatime'].dt.hour

# Group by 'hour' and calculate the mean for each parameter
hourly_avg = data.groupby('hour').mean()

# Plot each parameter separately by hour and save each plot
for column in hourly_avg.columns:
    if column != 'id':  # Exclude 'id' if it's not a relevant parameter
        plt.figure(figsize=(10, 6))
        plt.plot(hourly_avg.index, hourly_avg[column], marker='o', linestyle='-')
        plt.title(f"Average {column} by Hour of the Day")
        plt.xlabel("Hour of Day")
        plt.ylabel(f"Average {column}")
        plt.grid(True)
        plt.xticks(range(0, 24))  # X-axis ticks for each hour
        
        # Save the plot as a PNG file with the parameter name in the filename
        filename = f"average_{column}_by_hour.png"
        plt.savefig(filename, format='png')
        
        # Display the plot
        plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Convert 'datatime' column to datetime format if not already done
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the date (year-month-day) from 'datatime' for grouping
data['day'] = data['datatime'].dt.date

# Group by 'day' and calculate the mean for each parameter
daily_avg = data.groupby('day').mean()

# Create 'graph' folder if it doesn't exist
output_dir = "graph"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Plot each parameter separately by day and save each plot
for column in daily_avg.columns:
    if column != 'id':  # Exclude 'id' if it's not a relevant parameter
        plt.figure(figsize=(12, 6))
        plt.plot(daily_avg.index, daily_avg[column], marker='o', linestyle='-')
        plt.title(f"Average {column} by Day")
        plt.xlabel("Day")
        plt.ylabel(f"Average {column}")
        plt.grid(True)
        plt.xticks(rotation=45)  # Rotate day labels for readability
        
        # Save the plot as a PNG file in the 'graph' folder with the parameter name in the filename
        filename = os.path.join(output_dir, f"average_{column}_by_day.png")
        plt.savefig(filename, format='png')
        
        # Display the plot
        # plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Ensure 'datatime' column is in datetime format
data['datatime'] = pd.to_datetime(data['datatime'])

# Extract the hour from 'datatime' for grouping
data['hour'] = data['datatime'].dt.hour

# Group by 'hour' and calculate the mean for each parameter
hourly_avg = data.groupby('hour').mean().reset_index()

# List of parameters to plot (exclude 'id', 'datatime', and 'digital' columns)
parameters = [col for col in hourly_avg.columns if 'digital' not in col and col != 'id' and col != 'datatime']

# Generate and show a plot for each parameter
for column in parameters:
    # Create a figure for each parameter
    fig = go.Figure()

    fig.add_trace(
        go.Scatter(
            x=hourly_avg['hour'],
            y=hourly_avg[column],
            mode='lines+markers',
            name=column,
            line=dict(width=2),
            marker=dict(size=6)
        )
    )

    # Update layout for better presentation
    fig.update_layout(
        title=f"Average {column} by Hour of the Day",
        xaxis_title="Hour of Day",
        yaxis_title=f"Average {column}",
        hovermode="closest",
        template="plotly_dark",  # Use a dark theme for a beautiful look
        xaxis=dict(tickmode="linear", tick0=0, dtick=1),  # Set tick marks for each hour
        width=1000,
        height=600
    )

    # Show the interactive plot
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 23
#      17 for column in parameters:
#      18     # Create a figure for each parameter
#      19     fig = go.Figure()
#      21     fig.add_trace(
#      22         go.Scatter(
# ---> 23             x=hourly_avg['hour'],
#      24             y=hourly_avg[column],
#      25             mode='lines+markers',
#      26             name=column,
#      27             line=dict(width=2),
#      28             marker=dict(size=6)
#      29         )
#      30     )
#      32     # Update layout for better presentation
#      33     fig.update_layout(
#      34         title=f"Average {column} by Hour of the Day",
#      35         xaxis_title="Hour of Day",
#    (...)
#      41         height=600
#      42     )
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\shiva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hour'
